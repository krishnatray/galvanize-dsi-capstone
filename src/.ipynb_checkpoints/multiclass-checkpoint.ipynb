# %%
#!/usr/bin/env python
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate a word cloud image
text = open('test.py').read()
wordcloud = WordCloud().generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
import pandas as pd

# %%
df = pd.read_csv("corpus.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'physician_id', 'procedure_code',
#        'procedure', 'number_of_patients', 'id', 'specialty', 'is_cardiologist',
#        'corpus'],
#       dtype='object')

# %%
text = df.corpus[:1].to_string()

# %%
wordcloud = WordCloud().generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
cardiologists = df[df.is_cardiologist][:1000].corpus.str.cat()
non_cardiologists = df[~df.is_cardiologist][:1000].corpus.str.cat()

# %%
wordcloud = WordCloud(width=1920, height=1080).generate(cardiologists)
# Display the generated image:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud = WordCloud(width=1920, height=1080).generate(non_cardiologists)
# Display the generated image:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# top features
df_binary = pd.read_csv("top_features_binary.csv")

# %%
df_binary.head()
# Out:
#    Unnamed: 0  Importance    Feature
# 0           0      0.1891      heart
# 1           1      0.0866     report
# 2           2      0.0680      blood
# 3           3      0.0450      study
# 4           4      0.0370  typically

# %%
with open("top_features_binary.csv", mode= 'r') as f:
    f.readline()   # skip 1st row which is header
    feature_list = []
    for line in f:
        text = line.split(",")
        weight = int(float(text[1]) * 1000)
        word   = (text[2].strip() +" ") * weight
        feature_list.append(word)

# %%
wordcloud = WordCloud(width=1920, height=1080).generate(" ".join(feature_list))
# Display the generated image:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
with open("top_features_multiclass.csv", mode= 'r') as f:
    f.readline()   # skip 1st row which is header
    feature_list = []
    for line in f:
        text = line.split(",")
        weight = int(float(text[1]) * 1000)
        word   = (text[2].strip() +" ") * weight
        feature_list.append(word)

# %%
wordcloud = WordCloud(width=1920, height=1080).generate(" ".join(feature_list))
# Display the generated image:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
